# %%
print("The sort method arranges the elements of a list in ascending order")
print("For string, ASCII values are used and uppercase comes before lower case")
print("The reverse method reverses the elements in a list")

"""Examples and exercises"""
# Setup a list of numbers
num_list = [38, 92, 23, 16]
print(num_list)

# Sort the list
num_list.sort()
print(num_list)

# Setup a list of words
dance_list = ["Stepping", "Ballet", "Salsa", "Kathak", "Hopak", "Flamenco", "Dabke"]

# Reverse the list
dance_list.reverse()
print(dance_list)

# Sort the list
dance_list.sort()
print(dance_list)

board_games = ["go", "chess", "scrabble", "checkers"]
board_games.sort()
print(board_games)
board_games.reverse()
print(board_games)

num_list = [3, 32, -23, 699, 75, -101, 22, 45, 94, -3, 2]
# To arrange the numbers in ascending order
num_list.sort()
print(num_list)

#To arrange in descending order and print them
num_list.reverse()
print(num_list)
# Out:
# The sort method arranges the elements of a list in ascending order
# For string, ASCII values are used and uppercase comes before lower case
# The reverse method reverses the elements in a list
# [38, 92, 23, 16]
# [16, 23, 38, 92]
# ['Dabke', 'Flamenco', 'Hopak', 'Kathak', 'Salsa', 'Ballet', 'Stepping']
# ['Ballet', 'Dabke', 'Flamenco', 'Hopak', 'Kathak', 'Salsa', 'Stepping']
# ['checkers', 'chess', 'go', 'scrabble']
# ['scrabble', 'go', 'chess', 'checkers']
# [-101, -23, -3, 2, 3, 22, 32, 45, 75, 94, 699]
# [699, 94, 75, 45, 32, 22, 3, 2, -3, -23, -101]

# %%
print("The max function returns the largest element in a list")
print("The min function returns the smallest element in a list")
print("The sum functions returns the total of all the elements on the list")
print("These operations can only happen correctly if the elements are comparable")
print("The copy method is used to create a copy of the list")

"""Examples"""

# Set up a list of number
snum_list = [28, 92, 17, 3, -5, 999, 1]

# Set up a list of words
city_list = ["New York", "Missoula", "Chicago", "Bozeman", 
"Birmingham", "Austin", "Sacramento"]

# Usage of the max() funtion
print(max(snum_list))

# max() function works for strings as well
print(max(city_list))
    
# Usage of the min() funtion which also works for strings
print(min(snum_list))

print(min(city_list))

# sum() only works for a list of numbers
print(sum(snum_list))

print(min(snum_list))
festivals = ["Lollapalooza", "Coachella", "Newport Jazz festival", "Hardly Strictly Bluegrass", "Austin City Limits"]
print(min(festivals))
sum([1.2, 2.1, 3.2, 5.9])

"""practice"""
my_list = [1,2,3]
list2 = my_list
list2[0] = 13
print(sum(my_list))

my_list = [1,2,3]
list2 = my_list.copy()
list2[0] = 13
print(max(my_list))

my_list = ["cat", "dag", "hamster"]
list2 = my_list
list2[2] = "pigeon"

"""Make a copy of word_list called wisdom. Sort the list called wisdom. 
Create a sentence using the words in each list and print those sentences (no need to add periods at the end of the sentences)."""

word_list = ["exercise", "is", "truly", "a", "useful", "coding"]
wisdom = word_list.copy()
wisdom[0] = "Exercise everyday"
wisdom[1] = "Grass is green"
wisdom[2] = "It truly is"
wisdom[3] = "An apple a day keeps a doctor away and attracts isaac newton's ghost"
wisdom[4] = "Be useful, not perfect"
wisdom[5] = "I'm learning to code by coding"
print(wisdom)

# Create a copy called wisdom
wisdom = word_list.copy()

# Sort the wisdom list
wisdom.sort()

# Create empty strings
words = ""
wisdom_words = ""

for word in word_list:
    words += word + " " 

for word in wisdom:
    wisdom_words += word + " " 

print("words:", "".join(words))
print("words of wisdom:", "".join(wisdom_words))
# Out:
# The max function returns the largest element in a list
# The min function returns the smallest element in a list
# The sum functions returns the total of all the elements on the list
# These operations can only happen correctly if the elements are comparable
# The copy method is used to create a copy of the list
# 999
# Sacramento
# -5
# Austin
# 1135
# -5
# Austin City Limits
# 18
# 3
# ['Exercise everyday', 'Grass is green', 'It truly is', "An apple a day keeps a doctor away and attracts isaac newton's ghost", 'Be useful, not perfect', "I'm learning to code by coding"]
# words: exercise is truly a useful coding
# words of wisdom: a coding exercise is truly useful
